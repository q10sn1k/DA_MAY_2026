# %% [markdown]
# # Практикум для консультации: структура итоговой работы
#
# Этот notebook повторяет логику эталонного решения, но оставляет ключевые места для самостоятельного выполнения. Используйте его как чек-лист своей итоговой работы.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Находим корень проекта независимо от того, открыт notebook из корня или из папки notebooks.
candidates = [Path.cwd(), Path.cwd().parent]
PROJECT_ROOT = next((p for p in candidates if (p / 'data' / 'raw').exists()), Path.cwd())
RAW_DIR = PROJECT_ROOT / 'data' / 'raw'
PROCESSED_DIR = PROJECT_ROOT / 'data' / 'processed'
OUTPUT_DIR = PROJECT_ROOT / 'outputs'
OUTPUT_DIR.mkdir(exist_ok=True)

print('Корень проекта:', PROJECT_ROOT)
print('Исходные данные:', RAW_DIR)

# %% [markdown]
# ## 1. Загрузите четыре исходных таблицы и проверьте их размеры

# %%
# TODO: загрузите orders.csv, customers.csv, products.csv, regions.csv
orders = ...
customers = ...
products = ...
regions = ...

# %% [markdown]
# ## 2. Составьте диагностическую таблицу качества

# %%
# TODO: для каждой таблицы посчитайте строки, столбцы, пропуски и дубликаты
quality = ...
quality

# %% [markdown]
# ## 3. Выполните ETL

# %%
# TODO:
# 1. удалите дубли order_id;
# 2. приведите order_date к дате;
# 3. нормализуйте channel;
# 4. отфильтруйте quantity <= 0 и unit_price <= 0;
# 5. заполните region_id из customers;
# 6. объедините данные с products и regions.
clean = ...

# %% [markdown]
# ## 4. Рассчитайте показатели

# %%
# TODO: gross_order_value, discount_amount, recognized_revenue, gross_profit,
# margin_pct, is_returned, late_flag, order_month.

# %% [markdown]
# ## 5. Проведите EDA и постройте не менее пяти визуализаций

# %%
# TODO: динамика, категории, регионы, возвраты, SLA.

# %% [markdown]
# ## 6. Проверьте минимум три гипотезы

# %%
# TODO: сформулируйте H0/H1, выберите тест, рассчитайте p-value и сделайте вывод.

# %% [markdown]
# ## 7. Выполните RFM и ABC-XYZ

# %%
# TODO: создайте таблицы rfm_segments и abc_xyz_products.

# %% [markdown]
# ## 8. Сформируйте витрину для DataLens

# %%
# TODO: сохраните итоговый CSV в data/processed.

# %% [markdown]
# ## Самопроверка
#
# - Notebook запускается сверху вниз.
# - Используются относительные пути.
# - Описана гранулярность данных.
# - После каждого JOIN проверено количество строк.
# - Выводы содержат конкретные значения.
# - Статистический вывод отделен от визуального наблюдения.
# - Витрина DataLens содержит измерения, показатели и технические флаги.
