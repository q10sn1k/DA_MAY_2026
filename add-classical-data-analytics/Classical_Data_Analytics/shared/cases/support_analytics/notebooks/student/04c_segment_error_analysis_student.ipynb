# %% [markdown]
# # Анализ ошибок модели по сегментам
#
# Общая метрика может скрывать слабые зоны. В notebook качество классификатора оценивается по регионам, командам, каналам, категориям, приоритетам и сегментам клиентов.
#
# Результаты:
#
# - `outputs/segment_error_analysis.csv`;
# - `outputs/segment_alerts.csv`;
# - `outputs/charts/segment_recall.png`;
# - список сегментов, требующих доработки модели или процесса.

# %% [markdown]
# > **Место в производственном маршруте:** 8 из 9
# > **Ориентир очного занятия:** 355–370 минут
# > **Режим:** Управляемая практика
# > **Выход этапа:** Устойчивость по сегментам
#
# Студенческая версия содержит задания и контрольные точки без полного решения.

# %%
from pathlib import Path
import sys
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", category=FutureWarning)
pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 180)


def find_project_root(start: Path | None = None) -> Path:
    current = (start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "data" / "raw" / "tickets.csv").exists():
            return candidate
    raise FileNotFoundError(
        "Не найдена папка проекта. Убедитесь, что notebook находится внутри распакованного комплекта."
    )


PROJECT_ROOT = find_project_root()
RAW_DIR = PROJECT_ROOT / "data" / "raw"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
CHART_DIR = OUTPUT_DIR / "charts"
MODEL_DIR = PROJECT_ROOT / "models"

for directory in [OUTPUT_DIR, CHART_DIR, MODEL_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print("Python:", sys.version.split()[0])
print("Корень проекта:", PROJECT_ROOT)

# %%
calibrated_path = OUTPUT_DIR / "sla_risk_predictions_calibrated.csv"
base_path = OUTPUT_DIR / "sla_risk_predictions.csv"
source = calibrated_path if calibrated_path.exists() else base_path
if not source.exists():
    raise FileNotFoundError("Сначала выполните notebook 04 или 04b")

predictions = pd.read_csv(source, parse_dates=["created_date"])
print(predictions.shape)

# %% [markdown]
# ## Задание 1. Реализуйте функцию сегментных метрик

# %%
# Функция должна для каждого значения dimension вернуть:
# support, positive_rate, alert_rate, precision, recall, f1, TN, FP, FN, TP.

def segment_metrics(frame, dimension, min_support=50):
    # TODO
    return pd.DataFrame()

# %% [markdown]
# ## Задание 2. Рассчитайте метрики

# %%
dimensions = ["region_id", "team_id", "channel", "category", "priority", "customer_segment"]

# TODO: объедините результаты по всем измерениям.

# %% [markdown]
# ## Задание 3. Найдите слабые сегменты

# %%
# Рассчитайте общие precision и recall.
# Critical: recall ниже общего более чем на 0.15.
# Review: recall ниже общего более чем на 0.07.
# TODO: сформируйте status.

# %% [markdown]
# ## Задание 4. Подготовьте рекомендации

# %%
# Для каждого слабого сегмента укажите одну вероятную диагностическую ветку:
# - мало данных;
# - пропуски/ошибки источника;
# - изменение распределения;
# - недостаточные признаки;
# - отдельная стоимость ошибок.

# %% [markdown]
# ## Что сохранить
#
# - `outputs/segment_error_analysis.csv`;
# - `outputs/segment_alerts.csv`;
# - `outputs/charts/segment_recall.png`;
# - три абзаца: факт, возможное объяснение, следующий проверочный шаг.
