# %% [markdown]
# # Кластеризация команд поддержки
#
# Цель: получить интерпретируемые операционные профили команд.
#
# > Работайте последовательно и сохраняйте результаты в `outputs/`. После каждого раздела сверяйтесь с контрольной точкой. Полные решения в студенческой версии не приводятся.

# %% [markdown]
# > **Место в производственном маршруте:** 5 из 9
# > **Ориентир очного занятия:** 210–275 минут
# > **Режим:** Основной практический маршрут
# > **Выход этапа:** Профили команд
#
# Студенческая версия содержит задания и контрольные точки без полного решения.

# %%
from pathlib import Path
import sys
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", category=FutureWarning)
pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 180)


def find_project_root(start: Path | None = None) -> Path:
    current = (start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "data" / "raw" / "tickets.csv").exists():
            return candidate
    raise FileNotFoundError(
        "Не найдена папка проекта. Убедитесь, что notebook находится внутри распакованного комплекта."
    )


PROJECT_ROOT = find_project_root()
RAW_DIR = PROJECT_ROOT / "data" / "raw"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
CHART_DIR = OUTPUT_DIR / "charts"
MODEL_DIR = PROJECT_ROOT / "models"

for directory in [OUTPUT_DIR, CHART_DIR, MODEL_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print("Python:", sys.version.split()[0])
print("Корень проекта:", PROJECT_ROOT)
print("Исходные данные:", RAW_DIR)
print("Результаты:", OUTPUT_DIR)

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

analysis = pd.read_csv(OUTPUT_DIR / "analysis_base.csv", parse_dates=["created_date"])
capacity = pd.read_csv(OUTPUT_DIR / "team_capacity_clean.csv", parse_dates=["date"])
teams = pd.read_excel(RAW_DIR / "teams.xlsx")

# %% [markdown]
# ## Задание 1. Создайте одну строку на команду
#
# Рассчитайте показатели нагрузки, SLA, времени решения, CSAT, повторных открытий и мощности.

# %%
# TODO: создайте profile

# %% [markdown]
# ## Задание 2. Подготовьте признаки
#
# Выберите числовые признаки, обработайте пропуски и стандартизируйте их.

# %%
# TODO: X, scaler, X_scaled

# %% [markdown]
# ## Задание 3. Сравните `k=2..6`
#
# Для каждого `k` рассчитайте silhouette score, inertia и минимальный размер кластера.

# %%
# TODO: selection

# %% [markdown]
# ## Задание 4. Выберите число кластеров
#
# Обоснуйте решение не только максимальным score, но и интерпретируемостью. Постройте финальную модель.

# %%
# TODO: cluster_id

# %% [markdown]
# ## Задание 5. Дайте кластерам содержательные названия
#
# Номер кластера не является интерпретацией. Для каждой группы сформулируйте профиль, риск и возможное действие.

# %%
# TODO: cluster_name и cluster_summary

# %% [markdown]
# ## Задание 6. Визуализируйте результат
#
# Используйте PCA для двумерного отображения и подпишите команды.

# %%
# TODO: PCA-график

# %% [markdown]
# ## Самопроверка
#
# - [ ] одна строка соответствует одной команде;
# - [ ] признаки стандартизированы;
# - [ ] проверено несколько значений `k`;
# - [ ] нет кластеров из одного объекта без объяснения;
# - [ ] каждому кластеру дано содержательное название.
